# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 736

# %%
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
  
    city_url = url + "&q=" + city.replace(" ","+")

    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerres
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | stamsund
# City not found. Skipping...
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | simoes
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | roald
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | kununurra
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | coquimbo
# Processing Record 15 of Set 1 | palmer
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | ambulu
# Processing Record 19 of Set 1 | andenes
# Processing Record 20 of Set 1 | sirpur
# Processing Record 21 of Set 1 | harbour breton
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | sao joao da barra
# Processing Record 24 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 1 | ancud
# Processing Record 26 of Set 1 | longyearbyen
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | kampene
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | portland
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | higuey
# City not found. Skipping...
# Processing Record 33 of Set 1 | faanui
# Processing Record 34 of Set 1 | carnarvon
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | gerede
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | noumea
# Processing Record 39 of Set 1 | yarada
# Processing Record 40 of Set 1 | alugan
# Processing Record 41 of Set 1 | fairbanks
# Processing Record 42 of Set 1 | yar-sale
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | tura
# Processing Record 45 of Set 1 | royan
# Processing Record 46 of Set 1 | san miguel
# Processing Record 47 of Set 1 | koshurnikovo
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | namibe
# Processing Record 50 of Set 1 | klaksvik
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | cabra
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | cabo san lucas
# Processing Record 5 of Set 2 | tazmalt
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | hasaki
# Processing Record 9 of Set 2 | arman
# Processing Record 10 of Set 2 | eldikan
# City not found. Skipping...
# Processing Record 11 of Set 2 | san andres
# Processing Record 12 of Set 2 | yulara
# Processing Record 13 of Set 2 | neustadt
# Processing Record 14 of Set 2 | itacare
# Processing Record 15 of Set 2 | southport
# Processing Record 16 of Set 2 | susehri
# Processing Record 17 of Set 2 | nome
# Processing Record 18 of Set 2 | rawson
# Processing Record 19 of Set 2 | kieta
# Processing Record 20 of Set 2 | pevek
# Processing Record 21 of Set 2 | dongsheng
# Processing Record 22 of Set 2 | samana
# Processing Record 23 of Set 2 | east london
# Processing Record 24 of Set 2 | boquira
# Processing Record 25 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 2 | vestmanna
# Processing Record 27 of Set 2 | wyndham
# Processing Record 28 of Set 2 | bathsheba
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | hirara
# Processing Record 32 of Set 2 | kattivakkam
# Processing Record 33 of Set 2 | clyde river
# Processing Record 34 of Set 2 | egvekinot
# Processing Record 35 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 2 | huarmey
# Processing Record 37 of Set 2 | viedma
# Processing Record 38 of Set 2 | baoying
# Processing Record 39 of Set 2 | dolgoye
# Processing Record 40 of Set 2 | luganville
# Processing Record 41 of Set 2 | puerto narino
# Processing Record 42 of Set 2 | arraial do cabo
# Processing Record 43 of Set 2 | husavik
# Processing Record 44 of Set 2 | luderitz
# Processing Record 45 of Set 2 | agirish
# Processing Record 46 of Set 2 | makakilo city
# Processing Record 47 of Set 2 | novyy urengoy
# Processing Record 48 of Set 2 | leningradskiy
# Processing Record 49 of Set 2 | hovd
# Processing Record 50 of Set 2 | atar
# Processing Record 1 of Set 3 | castro
# Processing Record 2 of Set 3 | ipilan
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | cherskiy
# Processing Record 5 of Set 3 | xuddur
# Processing Record 6 of Set 3 | hamilton
# Processing Record 7 of Set 3 | port lincoln
# Processing Record 8 of Set 3 | filingue
# Processing Record 9 of Set 3 | ulaangom
# Processing Record 10 of Set 3 | beringovskiy
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | vardo
# Processing Record 13 of Set 3 | guymon
# Processing Record 14 of Set 3 | esso
# Processing Record 15 of Set 3 | gat
# Processing Record 16 of Set 3 | genhe
# Processing Record 17 of Set 3 | khandyga
# Processing Record 18 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 19 of Set 3 | la ronge
# Processing Record 20 of Set 3 | pelym
# Processing Record 21 of Set 3 | vila velha
# Processing Record 22 of Set 3 | black river
# Processing Record 23 of Set 3 | chuy
# Processing Record 24 of Set 3 | kaitangata
# Processing Record 25 of Set 3 | upernavik
# Processing Record 26 of Set 3 | bengkulu
# Processing Record 27 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 3 | tuy hoa
# Processing Record 29 of Set 3 | faya
# Processing Record 30 of Set 3 | orodara
# Processing Record 31 of Set 3 | yumen
# Processing Record 32 of Set 3 | puerto cabezas
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | qaanaaq
# Processing Record 35 of Set 3 | paamiut
# Processing Record 36 of Set 3 | kodiak
# Processing Record 37 of Set 3 | solnechnyy
# Processing Record 38 of Set 3 | fortuna
# Processing Record 39 of Set 3 | bluff
# Processing Record 40 of Set 3 | provideniya
# Processing Record 41 of Set 3 | dikson
# Processing Record 42 of Set 3 | khasan
# Processing Record 43 of Set 3 | arona
# Processing Record 44 of Set 3 | codrington
# Processing Record 45 of Set 3 | bardsir
# Processing Record 46 of Set 3 | turayf
# Processing Record 47 of Set 3 | port alfred
# Processing Record 48 of Set 3 | acarau
# Processing Record 49 of Set 3 | yuli
# Processing Record 50 of Set 3 | deputatskiy
# Processing Record 1 of Set 4 | cabaiguan
# Processing Record 2 of Set 4 | salalah
# Processing Record 3 of Set 4 | yelan
# Processing Record 4 of Set 4 | cape town
# Processing Record 5 of Set 4 | mar del plata
# Processing Record 6 of Set 4 | ilulissat
# Processing Record 7 of Set 4 | chernyshevskiy
# Processing Record 8 of Set 4 | llanes
# Processing Record 9 of Set 4 | lethem
# Processing Record 10 of Set 4 | sitka
# Processing Record 11 of Set 4 | lata
# Processing Record 12 of Set 4 | nyurba
# Processing Record 13 of Set 4 | gangapur
# Processing Record 14 of Set 4 | ormara
# Processing Record 15 of Set 4 | oistins
# Processing Record 16 of Set 4 | ostrovnoy
# Processing Record 17 of Set 4 | zhigansk
# Processing Record 18 of Set 4 | dunedin
# Processing Record 19 of Set 4 | vestmannaeyjar
# Processing Record 20 of Set 4 | gizo
# Processing Record 21 of Set 4 | broome
# Processing Record 22 of Set 4 | storforshei
# Processing Record 23 of Set 4 | norman wells
# Processing Record 24 of Set 4 | airai
# Processing Record 25 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 4 | narsaq
# Processing Record 27 of Set 4 | atuona
# Processing Record 28 of Set 4 | boende
# Processing Record 29 of Set 4 | cayenne
# Processing Record 30 of Set 4 | yellowknife
# Processing Record 31 of Set 4 | coihaique
# Processing Record 32 of Set 4 | lima
# Processing Record 33 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 4 | bambous virieux
# Processing Record 35 of Set 4 | fort nelson
# Processing Record 36 of Set 4 | tiksi
# Processing Record 37 of Set 4 | asyut
# Processing Record 38 of Set 4 | lagos
# Processing Record 39 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 4 | umm kaddadah
# Processing Record 41 of Set 4 | churapcha
# Processing Record 42 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 4 | himora
# City not found. Skipping...
# Processing Record 44 of Set 4 | deori khas
# Processing Record 45 of Set 4 | maragogi
# Processing Record 46 of Set 4 | praia da vitoria
# Processing Record 47 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 4 | lahij
# Processing Record 50 of Set 4 | kamaishi
# Processing Record 1 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 5 | kisangani
# Processing Record 3 of Set 5 | najran
# Processing Record 4 of Set 5 | lulea
# Processing Record 5 of Set 5 | bethel
# Processing Record 6 of Set 5 | tasiilaq
# Processing Record 7 of Set 5 | katsuura
# Processing Record 8 of Set 5 | pangnirtung
# Processing Record 9 of Set 5 | bucerias
# Processing Record 10 of Set 5 | nanortalik
# Processing Record 11 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 5 | lorengau
# Processing Record 13 of Set 5 | half moon bay
# Processing Record 14 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 5 | bhadreswar
# Processing Record 16 of Set 5 | braga
# Processing Record 17 of Set 5 | verkhnyaya maksakovka
# Processing Record 18 of Set 5 | soe
# Processing Record 19 of Set 5 | moorhead
# Processing Record 20 of Set 5 | grand gaube
# Processing Record 21 of Set 5 | vostok
# Processing Record 22 of Set 5 | constitucion
# Processing Record 23 of Set 5 | moga
# Processing Record 24 of Set 5 | severo-kurilsk
# Processing Record 25 of Set 5 | whitehorse
# Processing Record 26 of Set 5 | trat
# Processing Record 27 of Set 5 | college
# Processing Record 28 of Set 5 | moscow
# Processing Record 29 of Set 5 | pitimbu
# Processing Record 30 of Set 5 | souillac
# Processing Record 31 of Set 5 | barao de melgaco
# Processing Record 32 of Set 5 | goure
# Processing Record 33 of Set 5 | caravelas
# Processing Record 34 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 35 of Set 5 | padang
# Processing Record 36 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 5 | sinnamary
# Processing Record 38 of Set 5 | piuma
# Processing Record 39 of Set 5 | sorland
# Processing Record 40 of Set 5 | saint-francois
# Processing Record 41 of Set 5 | khailar
# Processing Record 42 of Set 5 | qaqortoq
# Processing Record 43 of Set 5 | altagracia de orituco
# Processing Record 44 of Set 5 | evensk
# Processing Record 45 of Set 5 | cidreira
# Processing Record 46 of Set 5 | san carlos de bariloche
# Processing Record 47 of Set 5 | jinxiang
# Processing Record 48 of Set 5 | saint-philippe
# Processing Record 49 of Set 5 | sao sebastiao
# Processing Record 50 of Set 5 | santa rosa
# Processing Record 1 of Set 6 | la cruz
# Processing Record 2 of Set 6 | sokolo
# Processing Record 3 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 6 | saint-denis
# Processing Record 5 of Set 6 | dire dawa
# Processing Record 6 of Set 6 | tadine
# Processing Record 7 of Set 6 | haines junction
# Processing Record 8 of Set 6 | bourail
# Processing Record 9 of Set 6 | brownsville
# Processing Record 10 of Set 6 | kuito
# Processing Record 11 of Set 6 | vao
# Processing Record 12 of Set 6 | tazovskiy
# Processing Record 13 of Set 6 | muros
# Processing Record 14 of Set 6 | khatanga
# Processing Record 15 of Set 6 | warrnambool
# Processing Record 16 of Set 6 | muroto
# Processing Record 17 of Set 6 | saskylakh
# Processing Record 18 of Set 6 | baishishan
# Processing Record 19 of Set 6 | asfi
# Processing Record 20 of Set 6 | carbonia
# Processing Record 21 of Set 6 | flagstaff
# Processing Record 22 of Set 6 | flinders
# Processing Record 23 of Set 6 | yima
# Processing Record 24 of Set 6 | tungor
# Processing Record 25 of Set 6 | cap-aux-meules
# Processing Record 26 of Set 6 | la asuncion
# Processing Record 27 of Set 6 | srednekolymsk
# Processing Record 28 of Set 6 | ponta do sol
# Processing Record 29 of Set 6 | ust-omchug
# Processing Record 30 of Set 6 | togur
# Processing Record 31 of Set 6 | toamasina
# Processing Record 32 of Set 6 | georgetown
# Processing Record 33 of Set 6 | kavieng
# Processing Record 34 of Set 6 | teya
# Processing Record 35 of Set 6 | esperance
# Processing Record 36 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 6 | lagoa
# Processing Record 38 of Set 6 | trinidad
# Processing Record 39 of Set 6 | bonthe
# Processing Record 40 of Set 6 | mogochin
# City not found. Skipping...
# Processing Record 41 of Set 6 | lakes entrance
# Processing Record 42 of Set 6 | auki
# Processing Record 43 of Set 6 | laguna
# Processing Record 44 of Set 6 | taltal
# Processing Record 45 of Set 6 | totoral
# Processing Record 46 of Set 6 | quatre cocos
# Processing Record 47 of Set 6 | eirunepe
# Processing Record 48 of Set 6 | mahebourg
# Processing Record 49 of Set 6 | rocha
# Processing Record 50 of Set 6 | geraldton
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 3 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 7 | san guillermo
# Processing Record 5 of Set 7 | moranbah
# Processing Record 6 of Set 7 | san patricio
# Processing Record 7 of Set 7 | khani
# Processing Record 8 of Set 7 | pouebo
# Processing Record 9 of Set 7 | tigil
# Processing Record 10 of Set 7 | rio grande
# Processing Record 11 of Set 7 | los llanos de aridane
# Processing Record 12 of Set 7 | raudeberg
# Processing Record 13 of Set 7 | adrar
# Processing Record 14 of Set 7 | shetpe
# Processing Record 15 of Set 7 | itaguai
# Processing Record 16 of Set 7 | san vicente
# Processing Record 17 of Set 7 | san rafael
# Processing Record 18 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 7 | bowen
# Processing Record 20 of Set 7 | aswan
# Processing Record 21 of Set 7 | kalmunai
# Processing Record 22 of Set 7 | kloulklubed
# Processing Record 23 of Set 7 | pasni
# Processing Record 24 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 7 | velingara
# Processing Record 26 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 27 of Set 7 | port macquarie
# Processing Record 28 of Set 7 | saurimo
# Processing Record 29 of Set 7 | linjiang
# Processing Record 30 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 7 | road town
# Processing Record 32 of Set 7 | abbeville
# Processing Record 33 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 7 | otane
# Processing Record 35 of Set 7 | bairiki
# Processing Record 36 of Set 7 | leshukonskoye
# Processing Record 37 of Set 7 | komsomolskiy
# Processing Record 38 of Set 7 | necochea
# Processing Record 39 of Set 7 | guerrero negro
# Processing Record 40 of Set 7 | pampas
# Processing Record 41 of Set 7 | semirom
# Processing Record 42 of Set 7 | bartica
# Processing Record 43 of Set 7 | florence
# Processing Record 44 of Set 7 | mount gambier
# Processing Record 45 of Set 7 | sabang
# Processing Record 46 of Set 7 | felidhoo
# City not found. Skipping...
# Processing Record 47 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 7 | rafaela
# Processing Record 49 of Set 7 | dwarka
# Processing Record 50 of Set 7 | masaki
# Processing Record 1 of Set 8 | ipubi
# Processing Record 2 of Set 8 | shenjiamen
# Processing Record 3 of Set 8 | ajdabiya
# Processing Record 4 of Set 8 | ribeira grande
# Processing Record 5 of Set 8 | birjand
# Processing Record 6 of Set 8 | amapa
# Processing Record 7 of Set 8 | augusto correa
# Processing Record 8 of Set 8 | victoria
# Processing Record 9 of Set 8 | port blair
# Processing Record 10 of Set 8 | wattegama
# Processing Record 11 of Set 8 | carutapera
# Processing Record 12 of Set 8 | novo aripuana
# Processing Record 13 of Set 8 | kiama
# Processing Record 14 of Set 8 | penzance
# Processing Record 15 of Set 8 | poum
# Processing Record 16 of Set 8 | ahipara
# Processing Record 17 of Set 8 | tukrah
# Processing Record 18 of Set 8 | taizhou
# Processing Record 19 of Set 8 | hailar
# Processing Record 20 of Set 8 | port elizabeth
# Processing Record 21 of Set 8 | general teran
# Processing Record 22 of Set 8 | kiunga
# Processing Record 23 of Set 8 | mitsamiouli
# Processing Record 24 of Set 8 | neuquen
# Processing Record 25 of Set 8 | manggar
# Processing Record 26 of Set 8 | williston
# Processing Record 27 of Set 8 | praia
# Processing Record 28 of Set 8 | pisco
# Processing Record 29 of Set 8 | tecoanapa
# Processing Record 30 of Set 8 | esik
# Processing Record 31 of Set 8 | ranong
# Processing Record 32 of Set 8 | krapivinskiy
# Processing Record 33 of Set 8 | russell
# Processing Record 34 of Set 8 | panama city
# Processing Record 35 of Set 8 | liberal
# Processing Record 36 of Set 8 | ahvaz
# Processing Record 37 of Set 8 | matara
# Processing Record 38 of Set 8 | tchibanga
# Processing Record 39 of Set 8 | ban nahin
# Processing Record 40 of Set 8 | muskegon
# Processing Record 41 of Set 8 | nouadhibou
# Processing Record 42 of Set 8 | cam ranh
# Processing Record 43 of Set 8 | maloy
# Processing Record 44 of Set 8 | kendari
# Processing Record 45 of Set 8 | yamada
# Processing Record 46 of Set 8 | sussex
# Processing Record 47 of Set 8 | sortland
# Processing Record 48 of Set 8 | kenai
# Processing Record 49 of Set 8 | buraydah
# Processing Record 50 of Set 8 | talnakh
# Processing Record 1 of Set 9 | nahavand
# Processing Record 2 of Set 9 | thio
# Processing Record 3 of Set 9 | saint anthony
# Processing Record 4 of Set 9 | solikamsk
# Processing Record 5 of Set 9 | nehe
# Processing Record 6 of Set 9 | ewa beach
# Processing Record 7 of Set 9 | aklavik
# Processing Record 8 of Set 9 | manono
# Processing Record 9 of Set 9 | priargunsk
# Processing Record 10 of Set 9 | beypur
# City not found. Skipping...
# Processing Record 11 of Set 9 | liepaja
# Processing Record 12 of Set 9 | sur
# Processing Record 13 of Set 9 | kahului
# Processing Record 14 of Set 9 | mizpe ramon
# City not found. Skipping...
# Processing Record 15 of Set 9 | belmonte
# Processing Record 16 of Set 9 | korla
# Processing Record 17 of Set 9 | save
# Processing Record 18 of Set 9 | abu zabad
# Processing Record 19 of Set 9 | inhambane
# Processing Record 20 of Set 9 | pizarro
# Processing Record 21 of Set 9 | marrakesh
# Processing Record 22 of Set 9 | richards bay
# Processing Record 23 of Set 9 | kindu
# Processing Record 24 of Set 9 | grand-santi
# Processing Record 25 of Set 9 | znamenskoye
# Processing Record 26 of Set 9 | maningrida
# Processing Record 27 of Set 9 | daru
# Processing Record 28 of Set 9 | acajutla
# Processing Record 29 of Set 9 | ottawa
# Processing Record 30 of Set 9 | idenao
# Processing Record 31 of Set 9 | marzuq
# Processing Record 32 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 9 | tutoia
# Processing Record 34 of Set 9 | xai-xai
# Processing Record 35 of Set 9 | smithers
# Processing Record 36 of Set 9 | coahuayana
# Processing Record 37 of Set 9 | ondjiva
# Processing Record 38 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 9 | jiuquan
# Processing Record 40 of Set 9 | hargeysa
# Processing Record 41 of Set 9 | pakdasht
# Processing Record 42 of Set 9 | lahaina
# Processing Record 43 of Set 9 | nueva italia
# Processing Record 44 of Set 9 | biak
# Processing Record 45 of Set 9 | ziro
# Processing Record 46 of Set 9 | fereydun kenar
# Processing Record 47 of Set 9 | chokwe
# Processing Record 48 of Set 9 | kushiro
# Processing Record 49 of Set 9 | kemijarvi
# Processing Record 50 of Set 9 | bonavista
# Processing Record 1 of Set 10 | dabat
# Processing Record 2 of Set 10 | lasa
# Processing Record 3 of Set 10 | rindal
# Processing Record 4 of Set 10 | altay
# Processing Record 5 of Set 10 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 6 of Set 10 | hambantota
# Processing Record 7 of Set 10 | copacabana
# Processing Record 8 of Set 10 | melfort
# Processing Record 9 of Set 10 | sangar
# Processing Record 10 of Set 10 | pochutla
# Processing Record 11 of Set 10 | kungurtug
# Processing Record 12 of Set 10 | tumpat
# Processing Record 13 of Set 10 | dalhousie
# Processing Record 14 of Set 10 | ustka
# Processing Record 15 of Set 10 | comodoro rivadavia
# Processing Record 16 of Set 10 | sabzevar
# Processing Record 17 of Set 10 | sedan
# Processing Record 18 of Set 10 | torata
# Processing Record 19 of Set 10 | iranshahr
# Processing Record 20 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 21 of Set 10 | beyneu
# Processing Record 22 of Set 10 | goderich
# Processing Record 23 of Set 10 | gushikawa
# Processing Record 24 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 10 | shakawe
# Processing Record 26 of Set 10 | ayia marina
# Processing Record 27 of Set 10 | boueni
# Processing Record 28 of Set 10 | saldanha
# Processing Record 29 of Set 10 | peniche
# Processing Record 30 of Set 10 | meulaboh
# Processing Record 31 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 32 of Set 10 | igarka
# Processing Record 33 of Set 10 | palauig
# Processing Record 34 of Set 10 | sabha
# Processing Record 35 of Set 10 | sakakah
# Processing Record 36 of Set 10 | puerto baquerizo moreno
# Processing Record 37 of Set 10 | kumphawapi
# Processing Record 38 of Set 10 | hornepayne
# Processing Record 39 of Set 10 | nanning
# Processing Record 40 of Set 10 | vetrisoaia
# Processing Record 41 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 10 | luau
# Processing Record 43 of Set 10 | scottsbluff
# Processing Record 44 of Set 10 | svetlogorsk
# Processing Record 45 of Set 10 | lompoc
# Processing Record 46 of Set 10 | tilichiki
# Processing Record 47 of Set 10 | alofi
# Processing Record 48 of Set 10 | doka
# Processing Record 49 of Set 10 | ataco
# Processing Record 50 of Set 10 | kasempa
# Processing Record 1 of Set 11 | kuching
# Processing Record 2 of Set 11 | skuodas
# Processing Record 3 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 4 of Set 11 | jinchang
# Processing Record 5 of Set 11 | dudinka
# Processing Record 6 of Set 11 | ha
# City not found. Skipping...
# Processing Record 7 of Set 11 | mari-turek
# Processing Record 8 of Set 11 | gazojak
# Processing Record 9 of Set 11 | sarlat-la-caneda
# Processing Record 10 of Set 11 | byron bay
# Processing Record 11 of Set 11 | lavrentiya
# Processing Record 12 of Set 11 | pokhara
# Processing Record 13 of Set 11 | farmington
# Processing Record 14 of Set 11 | ravar
# Processing Record 15 of Set 11 | aykhal
# Processing Record 16 of Set 11 | yendi
# Processing Record 17 of Set 11 | san pedro
# Processing Record 18 of Set 11 | livadiya
# Processing Record 19 of Set 11 | santa marinella
# Processing Record 20 of Set 11 | remiremont
# Processing Record 21 of Set 11 | taoudenni
# Processing Record 22 of Set 11 | barahona
# Processing Record 23 of Set 11 | uray
# Processing Record 24 of Set 11 | lipin bor
# Processing Record 25 of Set 11 | qujing
# Processing Record 26 of Set 11 | hirado
# Processing Record 27 of Set 11 | banjar
# Processing Record 28 of Set 11 | gloversville
# Processing Record 29 of Set 11 | greenville
# Processing Record 30 of Set 11 | port-gentil
# Processing Record 31 of Set 11 | morros
# Processing Record 32 of Set 11 | madimba
# Processing Record 33 of Set 11 | bossangoa
# Processing Record 34 of Set 11 | brae
# Processing Record 35 of Set 11 | sioux lookout
# Processing Record 36 of Set 11 | changping
# Processing Record 37 of Set 11 | dauphin
# Processing Record 38 of Set 11 | tres palos
# Processing Record 39 of Set 11 | boromo
# Processing Record 40 of Set 11 | sartana
# Processing Record 41 of Set 11 | nemuro
# Processing Record 42 of Set 11 | dzhebariki-khaya
# Processing Record 43 of Set 11 | chepareria
# Processing Record 44 of Set 11 | manakara
# Processing Record 45 of Set 11 | hofn
# Processing Record 46 of Set 11 | mende
# Processing Record 47 of Set 11 | pokosnoye
# Processing Record 48 of Set 11 | ambanja
# Processing Record 49 of Set 11 | itoman
# Processing Record 50 of Set 11 | manokwari
# Processing Record 1 of Set 12 | sibolga
# Processing Record 2 of Set 12 | jasper
# Processing Record 3 of Set 12 | sao filipe
# Processing Record 4 of Set 12 | wuda
# Processing Record 5 of Set 12 | mandalgovi
# Processing Record 6 of Set 12 | cedral
# Processing Record 7 of Set 12 | camabatela
# Processing Record 8 of Set 12 | ilabaya
# Processing Record 9 of Set 12 | tanout
# Processing Record 10 of Set 12 | atocha
# Processing Record 11 of Set 12 | oriximina
# Processing Record 12 of Set 12 | tevaitoa
# Processing Record 13 of Set 12 | westport
# Processing Record 14 of Set 12 | el tarra
# Processing Record 15 of Set 12 | waipawa
# Processing Record 16 of Set 12 | qianan
# Processing Record 17 of Set 12 | riyadh
# Processing Record 18 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 12 | virginia beach
# Processing Record 20 of Set 12 | rumphi
# Processing Record 21 of Set 12 | nishihara
# Processing Record 22 of Set 12 | bor
# Processing Record 23 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 12 | diapaga
# Processing Record 25 of Set 12 | mokhotlong
# Processing Record 26 of Set 12 | uyuni
# Processing Record 27 of Set 12 | esfahan
# Processing Record 28 of Set 12 | marshfield
# Processing Record 29 of Set 12 | san quintin
# Processing Record 30 of Set 12 | kruisfontein
# Processing Record 31 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 32 of Set 12 | maralal
# Processing Record 33 of Set 12 | talaya
# Processing Record 34 of Set 12 | mahajanga
# Processing Record 35 of Set 12 | cap malheureux
# Processing Record 36 of Set 12 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 37 of Set 12 | jingcheng
# Processing Record 38 of Set 12 | adet
# Processing Record 39 of Set 12 | okhotsk
# Processing Record 40 of Set 12 | kurali
# Processing Record 41 of Set 12 | hobyo
# Processing Record 42 of Set 12 | kailua
# Processing Record 43 of Set 12 | ushtobe
# Processing Record 44 of Set 12 | konin
# Processing Record 45 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 46 of Set 12 | sao miguel do araguaia
# Processing Record 47 of Set 12 | kukmor
# Processing Record 48 of Set 12 | yafran
# Processing Record 49 of Set 12 | sept-iles
# Processing Record 50 of Set 12 | tantangan
# Processing Record 1 of Set 13 | kungsbacka
# Processing Record 2 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 3 of Set 13 | emerald
# Processing Record 4 of Set 13 | itarema
# Processing Record 5 of Set 13 | katobu
# Processing Record 6 of Set 13 | dawlatabad
# Processing Record 7 of Set 13 | isangel
# Processing Record 8 of Set 13 | paso de patria
# Processing Record 9 of Set 13 | play cu
# City not found. Skipping...
# Processing Record 10 of Set 13 | kontagora
# Processing Record 11 of Set 13 | vila franca do campo
# Processing Record 12 of Set 13 | waingapu
# Processing Record 13 of Set 13 | opuwo
# Processing Record 14 of Set 13 | muli
# Processing Record 15 of Set 13 | baghdad
# Processing Record 16 of Set 13 | ciudad real
# Processing Record 17 of Set 13 | wahiawa
# Processing Record 18 of Set 13 | malanje
# Processing Record 19 of Set 13 | chunskiy
# Processing Record 20 of Set 13 | saquarema
# Processing Record 21 of Set 13 | manzanillo
# Processing Record 22 of Set 13 | caborca
# Processing Record 23 of Set 13 | salinas
# Processing Record 24 of Set 13 | grindavik
# Processing Record 25 of Set 13 | bayir
# Processing Record 26 of Set 13 | henties bay
# Processing Record 27 of Set 13 | la paz
# Processing Record 28 of Set 13 | oranjestad
# Processing Record 29 of Set 13 | jaisalmer
# Processing Record 30 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 13 | azar shahr
# City not found. Skipping...
# Processing Record 32 of Set 13 | vila do maio
# Processing Record 33 of Set 13 | berlevag
# Processing Record 34 of Set 13 | peace river
# Processing Record 35 of Set 13 | ouadda
# Processing Record 36 of Set 13 | shieli
# Processing Record 37 of Set 13 | maniitsoq
# Processing Record 38 of Set 13 | aden
# Processing Record 39 of Set 13 | wewak
# Processing Record 40 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 13 | mangai
# Processing Record 42 of Set 13 | lumut
# Processing Record 43 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 44 of Set 13 | puerto leguizamo
# Processing Record 45 of Set 13 | abnub
# Processing Record 46 of Set 13 | kuytun
# Processing Record 47 of Set 13 | havoysund
# Processing Record 48 of Set 13 | touros
# Processing Record 49 of Set 13 | darhan
# Processing Record 50 of Set 13 | siloam springs
# Processing Record 1 of Set 14 | iquitos
# Processing Record 2 of Set 14 | kushmurun
# Processing Record 3 of Set 14 | enshi
# Processing Record 4 of Set 14 | shevchenkove
# Processing Record 5 of Set 14 | paita
# Processing Record 6 of Set 14 | las vegas
# Processing Record 7 of Set 14 | houston
# Processing Record 8 of Set 14 | lavumisa
# Processing Record 9 of Set 14 | denpasar
# Processing Record 10 of Set 14 | porto novo
# Processing Record 11 of Set 14 | kursenai
# Processing Record 12 of Set 14 | novo cruzeiro
# Processing Record 13 of Set 14 | monkey bay
# Processing Record 14 of Set 14 | la palma
# Processing Record 15 of Set 14 | tiarei
# Processing Record 16 of Set 14 | oussouye
# Processing Record 17 of Set 14 | inuvik
# Processing Record 18 of Set 14 | basco
# Processing Record 19 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 14 | baykit
# Processing Record 21 of Set 14 | almeirim
# Processing Record 22 of Set 14 | dubbo
# Processing Record 23 of Set 14 | kavaratti
# Processing Record 24 of Set 14 | labuhan
# Processing Record 25 of Set 14 | ordynskoye
# Processing Record 26 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 27 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 14 | margate
# Processing Record 29 of Set 14 | akhalgori
# Processing Record 30 of Set 14 | tuatapere
# Processing Record 31 of Set 14 | makurdi
# Processing Record 32 of Set 14 | bardiyah
# Processing Record 33 of Set 14 | mardin
# Processing Record 34 of Set 14 | preston
# Processing Record 35 of Set 14 | lakhisarai
# Processing Record 36 of Set 14 | iqaluit
# Processing Record 37 of Set 14 | anahuac
# Processing Record 38 of Set 14 | pennsville
# Processing Record 39 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 14 | tres picos
# Processing Record 41 of Set 14 | clovis
# Processing Record 42 of Set 14 | araouane
# Processing Record 43 of Set 14 | hoyerswerda
# Processing Record 44 of Set 14 | kingisepp
# Processing Record 45 of Set 14 | isiolo
# Processing Record 46 of Set 14 | vangaindrano
# Processing Record 47 of Set 14 | pingliang
# Processing Record 48 of Set 14 | rudbar
# Processing Record 49 of Set 14 | ngunguru
# Processing Record 50 of Set 14 | gorele
# Processing Record 1 of Set 15 | alindao
# Processing Record 2 of Set 15 | nador
# Processing Record 3 of Set 15 | jacqueville
# Processing Record 4 of Set 15 | soyo
# Processing Record 5 of Set 15 | dagana
# Processing Record 6 of Set 15 | ardrishaig
# Processing Record 7 of Set 15 | vinh
# Processing Record 8 of Set 15 | atlantic city
# Processing Record 9 of Set 15 | ca mau
# Processing Record 10 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 15 | cabedelo
# Processing Record 12 of Set 15 | malya
# Processing Record 13 of Set 15 | pueblo
# Processing Record 14 of Set 15 | west wendover
# Processing Record 15 of Set 15 | ambon
# Processing Record 16 of Set 15 | mackenzie
# Processing Record 17 of Set 15 | imbituba
# Processing Record 18 of Set 15 | kilindoni
# Processing Record 19 of Set 15 | kalia
# Processing Record 20 of Set 15 | petit goave
# Processing Record 21 of Set 15 | kem
# Processing Record 22 of Set 15 | hami
# Processing Record 23 of Set 15 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 24 of Set 15 | novoagansk
# Processing Record 25 of Set 15 | nagato
# Processing Record 26 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 27 of Set 15 | mindelo
# Processing Record 28 of Set 15 | nyrob
# Processing Record 29 of Set 15 | ocean city
# Processing Record 30 of Set 15 | havelock
# Processing Record 31 of Set 15 | ergani
# Processing Record 32 of Set 15 | pervomayskoye
# Processing Record 33 of Set 15 | lucapa
# Processing Record 34 of Set 15 | kargasok
# Processing Record 35 of Set 15 | mugur-aksy
# Processing Record 36 of Set 15 | high level
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 673

# %%
city_data_df= pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Puerres   1.1937  -77.2666     47.35        87          42
# 1        Hobart -42.8794  147.3294     55.26        81          75
# 2    Bredasdorp -34.5322   20.0403     50.56        89          91
# 3        Simoes  -7.5989  -40.8178     70.92        82          13
# 4  Puerto Ayora  -0.7393  -90.3518     72.55        89          56
# 5         Roald  62.5833    6.1333     57.33       100           0
# 6     Hithadhoo  -0.6000   73.0833     83.43        68          75
# 7       Mataura -46.1927  168.8643     52.48        66          12
# 8     Kununurra -15.7667  128.7333     82.38        20           2
# 9  Punta Arenas -53.1500  -70.9167     32.11        80          40
#
#    Wind Speed Country Current Description
# 0        6.53      CO    scattered clouds
# 1        3.00      AU       broken clouds
# 2        5.77      ZA     overcast clouds
# 3       16.06      BR          few clouds
# 4        8.99      EC       broken clouds
# 5        4.61      NO           clear sky
# 6       12.17      MV       broken clouds
# 7        1.95      NZ          few clouds
# 8       14.97      AU           clear sky
# 9       11.50      CL    scattered clouds

# %%
# Reorder columns
new_column_order=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df= city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Puerres      CO   1.1937  -77.2666     47.35        87          42
# 1        Hobart      AU -42.8794  147.3294     55.26        81          75
# 2    Bredasdorp      ZA -34.5322   20.0403     50.56        89          91
# 3        Simoes      BR  -7.5989  -40.8178     70.92        82          13
# 4  Puerto Ayora      EC  -0.7393  -90.3518     72.55        89          56
# 5         Roald      NO  62.5833    6.1333     57.33       100           0
# 6     Hithadhoo      MV  -0.6000   73.0833     83.43        68          75
# 7       Mataura      NZ -46.1927  168.8643     52.48        66          12
# 8     Kununurra      AU -15.7667  128.7333     82.38        20           2
# 9  Punta Arenas      CL -53.1500  -70.9167     32.11        80          40
#
#    Wind Speed Current Description
# 0        6.53    scattered clouds
# 1        3.00       broken clouds
# 2        5.77     overcast clouds
# 3       16.06          few clouds
# 4        8.99       broken clouds
# 5        4.61           clear sky
# 6       12.17       broken clouds
# 7        1.95          few clouds
# 8       14.97           clear sky
# 9       11.50    scattered clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
